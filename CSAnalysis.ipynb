# %% [markdown]
# ### Performance Analysis
#
# Relevant variables: **performance_viewpoint_comparison**, **performance_difficulty_significance**, **performance_viewpoint_difficulty_comparison**

# %%
# %run AnalysisScripts/PerformanceAnalysis.py
# Out:
# Analyzing metric: MeanAccuracy
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanPrecision
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanRecall
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanF1Score
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanCompletionTime
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanDPrime
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanBeta
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanSpecificity
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanTruePositive
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: MeanFalsePositive
#
# Analyzing task: denoising
#
# Analyzing task: seperating

# %% [markdown]
# ### Selection Analysis
#
# Relevant variables: **selection_viewpoint_comparison**

# %%
# %run AnalysisScripts/SelectionAnalysis.py
# Out:
# Analyzing metric: LassoInteractions
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: RaycastInteractions
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: TotalLassoPoints
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: TotalRaycastPoints
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: LassoActionPercentage
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: RaycastActionPercentage
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: LassoPointsPercentage
#
# Analyzing task: denoising
#
# Analyzing task: seperating
#
# Analyzing metric: RaycastPointsPercentage
#
# Analyzing task: denoising
#
# Analyzing task: seperating

# %% [markdown]
# ### Navigation Analysis
#
# Relevant variables: **movement_change_results**, **viewpoint_looktime_comparison**, **viewpoint_looktime_difficulty_comparison**

# %%
# %run AnalysisScripts/NavigationAnalysis.py
# Out:
# Analyzing task: denoising
#
# Analyzing task: seperating
